# %% [markdown]
# Notebook for the study of normalization techniques with deep learning models.

# %%
import pandas as pd 
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# %%
df_trajectory = pd.read_csv('TLRDGTUSTUAEMAIIHFFEDNTSL_20221201_ContextId_5_TrackId_118690_2022-12-01_13-43_NotAvailable.csv')
df_trajectory.head()
# Out:
#        ID  DeviceID  ContextID  DeviceTrackID  ScenarioTrackID  \
# 0  118690        18          5          23974           118690
# 1  118690        18          5          23974           118690
# 2  118690        18          5          23974           118690
# 3  118690        18          5          23974           118690
# 4  118690        18          5          23974           118690
#
#    ScenarioTimeStamp  LockedID  ScanNumber  ScenarioCoordinate1  \
# 0       1.669902e+09         0       11169            -1.633530
# 1       1.669902e+09         0       11170            -1.633655
# 2       1.669902e+09         0       11171            -1.633785
# 3       1.669902e+09         0       11172            -1.633978
# 4       1.669902e+09         0       11173            -1.634286
#
#    ScenarioCoordinate2  ...  AngularSize  Detections        Power     Clutter  \
# 0            42.246939  ...            5           5   415.142822  157.428574
# 1            42.246800  ...            5           5   415.142822  157.428574
# 2            42.246648  ...            4           4   246.285721  103.428574
# 3            42.246536  ...            6          11  1000.000000  389.714294
# 4            42.246457  ...            3           3   169.714294   90.428574
#
#    Doppler  Rcs     Type  UpdateType  LifeTime  ActiveTime
# 0      0.0    0  Unknown        Gain      5000         0.0
# 1      0.0    0  Unknown      Update      5000         1.0
# 2      0.0    0  Unknown      Update      5000         2.0
# 3      0.0    0  Unknown      Update      5000         3.0
# 4      0.0    0  Unknown      Update      5000         4.0
#
# [5 rows x 37 columns]

# %%
fig = plt.figure(figsize = (10,10))
ax = plt.axes(projection='3d')
x = df_trajectory['DeviceCoordinate1']
y = df_trajectory['DeviceCoordinate2']
z = df_trajectory['DeviceCoordinate3']

ax.plot3D(x,y,z)

plt.show()

# %%
fig2 = plt.figure(figsize = (10,10))
ax2 = plt.axes()

ax2.plot(x,y)
ax2.scatter(x,y)
plt.show()
